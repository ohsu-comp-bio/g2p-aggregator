# %% [markdown]
# # Variant-Condition Observation
# > Contributors: MHB, FJL, MG, BW
# > Definition: an annotation about the observation of a variant in a case of a particular type of condition (i.e in a > patient or biospecimen bearing the condition)

# %% [markdown]
# ### Etiopathogenesis
# > The cause and subsequent development of an abnormal condition or of a disease.
#
# ### Impact of existing evidence
# > AMP/CAP/ASCO Somatic Interpretation Guidelines
# > Key task for defining requirements here will be to review and document what types of information is used as evidence for this type of variant annotation.
#
#
# #### Given a corpus of evidence (81K uncurated PUBMED articles), what can we learn from it?
#
# * [LitVar](https://www.ncbi.nlm.nih.gov/CBBresearch/Lu/Demo/LitVar/#) allows the search and retrieval of variant relevant information from the biomedical literature and shows key biological relations between a variant and its close related entities (e.g. genes, diseases, and drugs).  [NAR 2018](https://academic.oup.com/nar/article/46/W1/W530/4995688)

# %% [markdown]
# ## What are the characteristics of the edge (join) between Variant and Condition?

# %%
from litvar_notebook import load, plot_variant_by_disease, singular_vs_plural_evidence, genes_only_vs_has_variants, publication_concepts_scatter, top_verbs

counts, description_verbs = load()
plot_variant_by_disease(counts)

# %% [markdown]
# ## Most publications consider sets of items
# Singular: at most one of any gene, disease, variant

# %%
singular_vs_plural_evidence(counts)

# %% [markdown]
# ## Many publications only mention genes

# %%
genes_only_vs_has_variants(counts)

# %% [markdown]
# ## Miscellaneous correlations

# %%
publication_concepts_scatter(counts)

# %% [markdown]
# ## What is our vocabulary for assertations?
#
#
# > Assertation: A statement of purported truth, as made by a
#  particular agent on a particular occasion. [SEPIO]
#
#
#
# > Author statement: An evidence type that is based on an assertion by the author of a paper, which is read by a curator. [ECO:MCC]
# > Term id:	ECO:0000204
# > Term name:	author statement
# > Definition:	An evidence type that is based on an assertion by the author of a paper, which is read by a curator. [ECO:MCC]
#
# What are the top 50 verbs used in descriptions?

# %%
top_verbs(description_verbs)

# %% [markdown]
# ## Questions:
# * What is our vocabulary for Propositions?
# * How might we arrive at a worked example for `Supporting Data`?
# * Is our primary use case to encourage new experiments to publish using our new model, or to 'harvest' mineable publications?
#
#
# > Proposition: The ‘sharable’ meaning of what is expressed in a
# particular assertion.  Evidence for a claim includes any information that is used to
# evaluate the validity of its proposition  [SEPIO]
#
#
#
# ![image](https://user-images.githubusercontent.com/47808/44173566-2c622180-a095-11e8-8ac7-d37931efd74f.png)
#
# https://pdfs.semanticscholar.org/00c8/4db022e12574ac2df4aba1e8560181081bce.pdf
